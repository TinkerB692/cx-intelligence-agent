# %%
import pandas as pd

# %%
# Load the dataset
df = pd.read_csv("data/raw/customer_support_tickets.csv")
df.head()

# %%
# Clean and standardize column names
df.columns = df.columns.str.lower().str.strip().str.replace(" ", "_")
df = df.rename(columns={"ticket_id": "id"})
df.head()
